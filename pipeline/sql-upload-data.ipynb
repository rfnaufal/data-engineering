# %%
import pandas as pd

# %%
# !wget https://s3.amazonaws.com/nyc-tlc/misc/taxi+_zone_lookup.csv
# Out:
# --2026-01-23 08:18:27--  https://s3.amazonaws.com/nyc-tlc/misc/taxi+_zone_lookup.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.73.246, 16.15.179.52, 52.217.225.8, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.73.246|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2026-01-23 08:18:28 ERROR 403: Forbidden.

# %%
# !wget https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv
# Out:
# --2026-01-23 08:19:17--  https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/513814948/5a2cc2f5-b4cd-4584-9c62-a6ea97ed0e6a?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-01-23T08%3A58%3A27Z&rscd=attachment%3B+filename%3Dtaxi_zone_lookup.csv&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-01-23T07%3A58%3A06Z&ske=2026-01-23T08%3A58%3A27Z&sks=b&skv=2018-11-09&sig=53e1VpN9JVMgyMyhV4AyF8z2E6VpL3zaZAHhc8Yoh%2FQ%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2OTE1NjY1NywibmJmIjoxNzY5MTU2MzU3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.jPS4jW2YO7zLsxdQvFNCcAaAM1Eom8cX0sZurqyZpTQ&response-content-disposition=attachment%3B%20filename%3Dtaxi_zone_lookup.csv&response-content-type=application%2Foctet-stream [following]
# --2026-01-23 08:19:17--  https://release-assets.githubusercontent.com/github-production-release-asset/513814948/5a2cc2f5-b4cd-4584-9c62-a6ea97ed0e6a?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-01-23T08%3A58%3A27Z&rscd=attachment%3B+filename%3Dtaxi_zone_lookup.csv&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-01-23T07%3A58%3A06Z&ske=2026-01-23T08%3A58%3A27Z&sks=b&skv=2018-11-09&sig=53e1VpN9JVMgyMyhV4AyF8z2E6VpL3zaZAHhc8Yoh%2FQ%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2OTE1NjY1NywibmJmIjoxNzY5MTU2MzU3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.jPS4jW2YO7zLsxdQvFNCcAaAM1Eom8cX0sZurqyZpTQ&response-content-disposition=attachment%3B%20filename%3Dtaxi_zone_lookup.csv&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12322 (12K) [application/octet-stream]
# Saving to: ‘taxi_zone_lookup.csv’
#
# taxi_zone_lookup.cs 100%[===================>]  12.03K  --.-KB/s    in 0s
#
# 2026-01-23 08:19:17 (71.2 MB/s) - ‘taxi_zone_lookup.csv’ saved [12322/12322]

# %%
df_zones = pd.read_csv('taxi_zone_lookup.csv')

# %%
df_zones.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
df_zones.to_sql(name='zones', con=engine, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_zones.to_sql(name='zones', con=engine, if_exists='replace')
#
# NameError: name 'engine' is not defined

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
df_zones.to_sql(name='zones', con=engine, if_exists='replace')
# Out:
# 265

# %%
len(df_zones)
# Out:
# 265

# %%
df_zones.shape[0]
# Out:
# 265
